# %% [markdown]
# # Zigarettenkonsum
#
#
# https://tobaccoatlas.org/topic/consumption/
#
# Diese Daten haben keinen direkten Einfluss auf die COVID 19 Ausbreitung, aber sie sind von Interesse, wenn die Sterblichkeitsraten betrachtet werden.
#
# Die Spalte "Cigarette consumption" gibt an wie viele Zigaretten pro perso pro Jahr geraucht werden. (ab einem Alter >= 15 Jahre)
#
# von 2016

# %%
import pandas as pd

df = pd.read_csv("./data/consumption-map.csv")
df.head()
# Out:
#          COUNTRY ISO3 CODE REGION INCOME GROUP  2015 HDI HDI classification  \
# 0        Andorra       AND   EURO         HIGH     0.858          Very high
# 1          Lux.        LUX   EURO         HIGH     0.898          Very high
# 2        Belarus       BLR   EURO       MIDDLE     0.796               High
# 3  FYR Macedonia       MKD   EURO       MIDDLE     0.748               High
# 4        Albania       ALB   EURO       MIDDLE     0.764               High
#
#    Cigarette consumption  Key code  Symbol
# 0            6398.300003       5.0     1.0
# 1            6330.872751       5.0     1.0
# 2            2911.297899       5.0     1.0
# 3            2784.928251       5.0     NaN
# 4            2491.599232       5.0     1.0
