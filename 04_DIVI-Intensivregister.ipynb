# %% [markdown]
# # DIVI Intensivregister
#
# Enthält Daten zu den deutschen aktuellen Intensivkapazitäten.

# %% [markdown]
# Die Daten stehen für jeden Tag **seperat** zum Download bereit.
#
# https://www.divi.de/divi-intensivregister-tagesreport-archiv/?limit=30&limitstart=0
#
# ## Beispiel **DIVI-Intensivregister_2020-05-15.csv**

# %%
import pandas as pd

df = pd.read_csv('./data/divi-intensivregister/DIVI-Intensivregister_2020-05-15.csv', parse_dates = ['daten_stand'])
df.head()
# Out:
#    bundesland  gemeindeschluessel  anzahl_meldebereiche  faelle_covid_aktuell  \
# 0           1                1001                     2                     1
# 1           1                1002                     5                     2
# 2           1                1003                     2                     2
# 3           1                1004                     1                     0
# 4           1                1051                     1                     2
#
#    faelle_covid_aktuell_beatmet  anzahl_standorte  betten_frei  betten_belegt  \
# 0                             1                 2           50             35
# 1                             1                 3          121            120
# 2                             2                 2          111            112
# 3                             0                 1           20             20
# 4                             2                 1           56             31
#
#           daten_stand
# 0 2020-05-15 09:15:00
# 1 2020-05-15 09:15:00
# 2 2020-05-15 09:15:00
# 3 2020-05-15 09:15:00
# 4 2020-05-15 09:15:00

# %% [markdown]
# ## Download
#
# Die Daten wurden aktuell händisch heruntergeladen und in `./data/div-intensivregister/` abgelegt.
#
# Zunkünfitg müsste man hier einen Webcrawler bauen und die links zum Download aus der Website extrahieren und programmatisch aufrufen.

# %% [markdown]
# ## Zusammenfassen zu einem CSV
#
# ### Imports und in das richtige Verzeichnis wechseln.

# %%
import os
import glob

os.chdir('./data/divi-intensivregister/')
if (os.path.isfile('divi_15_05_till_15_06.csv')):
    os.remove('divi_15_05_till_15_06.csv')

# %% [markdown]
# ### Einlesend der Dateinamen

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

# %% [markdown]
# ### Dateinamen-Array durchlaufen und alle CSVs zusammenfassen

# %%
csv_array = []
rows_ges = 0

for f in all_filenames:
    csv_i = pd.read_csv(f)
    rowcount_i = len(csv_i.index)
    rows_ges += rowcount_i
    print('Read csv: ', f)
    print('Rows: ', rowcount_i)
    csv_array.append(csv_i)
    
combined_csv = pd.concat(csv_array)
combined_csv = combined_csv.sort_values('daten_stand')
print('rows_ges: ', rows_ges)
# Out:
# Read csv:  DIVI-Intensivregister_2020-06-02.csv
# Rows:  397
# Read csv:  DIVI-Intensivregister_2020-06-03.csv
# Rows:  397
# Read csv:  DIVI-Intensivregister_2020-06-01.csv
# Rows:  394
# Read csv:  DIVI-Intensivregister_2020-06-15.csv
# Rows:  393
# Read csv:  DIVI-Intensivregister_2020-06-14.csv
# Rows:  395
# Read csv:  DIVI-Intensivregister_2020-06-04.csv
# Rows:  397
# Read csv:  DIVI-Intensivregister_2020-06-10.csv
# Rows:  397
# Read csv:  DIVI-Intensivregister_2020-06-11.csv
# Rows:  396
# Read csv:  DIVI-Intensivregister_2020-06-05.csv
# Rows:  397
# Read csv:  DIVI-Intensivregister_2020-06-13.csv
# Rows:  395
# Read csv:  DIVI-Intensivregister_2020-06-07.csv
# Rows:  397
# Read csv:  DIVI-Intensivregister_2020-06-06.csv
# Rows:  397
# Read csv:  DIVI-Intensivregister_2020-06-12.csv
# Rows:  396
# Read csv:  DIVI-Intensivregister_2020-05-18.csv
# Rows:  392
# Read csv:  DIVI-Intensivregister_2020-05-24.csv
# Rows:  395
# Read csv:  DIVI-Intensivregister_2020-05-30.csv
# Rows:  397
# Read csv:  DIVI-Intensivregister_2020-05-31.csv
# Rows:  396
# Read csv:  DIVI-Intensivregister_2020-05-25.csv
# Rows:  394
# Read csv:  DIVI-Intensivregister_2020-05-19.csv
# Rows:  394
# Read csv:  DIVI-Intensivregister_2020-05-27.csv
# Rows:  397
# Read csv:  DIVI-Intensivregister_2020-05-26.csv
# Rows:  397
# Read csv:  DIVI-Intensivregister_2020-05-22.csv
# Rows:  394
# Read csv:  DIVI-Intensivregister_2020-05-23.csv
# Rows:  395
# Read csv:  DIVI-Intensivregister_2020-05-21.csv
# Rows:  395
# Read csv:  DIVI-Intensivregister_2020-05-20.csv
# Rows:  395
# Read csv:  DIVI-Intensivregister_2020-05-17.csv
# Rows:  393
# Read csv:  DIVI-Intensivregister_2020-05-16.csv
# Rows:  394
# Read csv:  DIVI-Intensivregister_2020-05-28.csv
# Rows:  397
# Read csv:  DIVI-Intensivregister_2020-05-29.csv
# Rows:  397
# Read csv:  DIVI-Intensivregister_2020-05-15.csv
# Rows:  394
# Read csv:  DIVI-Intensivregister_2020-06-08.csv
# Rows:  395
# Read csv:  DIVI-Intensivregister_2020-06-09.csv
# Rows:  397
# rows_ges:  12656

# %%
combined_csv.head()
# Out:
#      bundesland  gemeindeschluessel  anzahl_meldebereiche  \
# 99            5                5758                     4
# 125           6                6436                     2
# 126           6                6437                     2
# 127           6                6438                     2
# 128           6                6439                     2
#
#      faelle_covid_aktuell  faelle_covid_aktuell_beatmet  anzahl_standorte  \
# 99                      2                             2                 3
# 125                     2                             2                 2
# 126                     8                             8                 2
# 127                     9                             8                 2
# 128                     1                             1                 2
#
#      betten_frei  betten_belegt          daten_stand
# 99            27             45  2020-05-15 09:15:00
# 125           13             24  2020-05-15 09:15:00
# 126           25            117  2020-05-15 09:15:00
# 127           19             36  2020-05-15 09:15:00
# 128           14              8  2020-05-15 09:15:00

# %%
combined_csv.tail()
# Out:
#      bundesland  gemeindeschluessel  anzahl_meldebereiche  \
# 264           9                9461                     4
# 265           9                9462                     5
# 266           9                9463                     1
# 268           9                9471                     1
# 195           8                8222                     5
#
#      faelle_covid_aktuell  faelle_covid_aktuell_beatmet  anzahl_standorte  \
# 264                     0                             0                 1
# 265                     0                             0                 2
# 266                     2                             2                 1
# 268                     0                             0                 1
# 195                     1                             1                 3
#
#      betten_frei  betten_belegt          daten_stand
# 264           34             24  2020-06-15 09:15:00
# 265           15             44  2020-06-15 09:15:00
# 266            6             30  2020-06-15 09:15:00
# 268            6              2  2020-06-15 09:15:00
# 195           17            110  2020-06-15 09:15:00

# %% [markdown]
# ### DataFrame als CSV schreiben

# %%
combined_csv.to_csv( "divi_15_05_till_15_06.csv", index=False, encoding='utf-8-sig')
os.chdir('../../')

# %% [markdown]
# ### CSV einlesen und validieren

# %%
dfCombined = pd.read_csv('./data/divi-intensivregister/divi_15_05_till_15_06.csv', parse_dates = ['daten_stand'])
dfCombined.head()
# Out:
#    bundesland  gemeindeschluessel  anzahl_meldebereiche  faelle_covid_aktuell  \
# 0           5                5758                     4                     2
# 1           6                6436                     2                     2
# 2           6                6437                     2                     8
# 3           6                6438                     2                     9
# 4           6                6439                     2                     1
#
#    faelle_covid_aktuell_beatmet  anzahl_standorte  betten_frei  betten_belegt  \
# 0                             2                 3           27             45
# 1                             2                 2           13             24
# 2                             8                 2           25            117
# 3                             8                 2           19             36
# 4                             1                 2           14              8
#
#           daten_stand
# 0 2020-05-15 09:15:00
# 1 2020-05-15 09:15:00
# 2 2020-05-15 09:15:00
# 3 2020-05-15 09:15:00
# 4 2020-05-15 09:15:00

# %%
a = dfCombined.daten_stand.value_counts().sort_index()
print('Das erste Datum:',a.index[0])
print('Das letzte Datum:',a.index[-1])
print('Expected rowCount: ', rows_ges)
print('Actual rowCount:', len(dfCombined.index))
# Out:
# Das erste Datum: 2020-05-15 09:15:00
# Das letzte Datum: 2020-06-15 09:15:00
# Expected rowCount:  12656
# Actual rowCount: 12656
